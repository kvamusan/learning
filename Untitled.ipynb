# %%
# running the Stanford POS Tagger from NLTK
 
import nltk
from nltk import word_tokenize
from nltk import StanfordTagger
 
text_tok = nltk.word_tokenize("Just a small snippet of text.")
 
# print(text_tok)
pos_tagged = nltk.pos_tag(text_tok)
 
# print the list of tuples: (word,word_class)
print(pos_tagged)
 
# for loop to extract the elements of the tuples in the pos_tagged list
# print the word and the pos_tag with the underscore as a delimiter
for word,word_class in pos_tagged:
    print(word + "_" + word_class)
# Out:
# [('Just', 'RB'), ('a', 'DT'), ('small', 'JJ'), ('snippet', 'NN'), ('of', 'IN'), ('text', 'NN'), ('.', '.')]
# Just_RB
# a_DT
# small_JJ
# snippet_NN
# of_IN
# text_NN
# ._.

# %%
import nltk
from nltk import word_tokenize
from nltk import StanfordTagger

# Tokenize the text
text_tok = nltk.word_tokenize("Just a small snippet of text.")

# Perform POS tagging using NLTK
pos_tagged = nltk.pos_tag(text_tok)

# Print the list of tuples: (word, word_class)
print(pos_tagged)

# For loop to extract the elements of the tuples in the pos_tagged list
# Print the word and the pos_tag with the underscore as a delimiter
for word, word_class in pos_tagged:
    print(word + "_" + word_class)
# Out:
# [('Just', 'RB'), ('a', 'DT'), ('small', 'JJ'), ('snippet', 'NN'), ('of', 'IN'), ('text', 'NN'), ('.', '.')]
# Just_RB
# a_DT
# small_JJ
# snippet_NN
# of_IN
# text_NN
# ._.

# %%
import nltk

# Define the file path
file_path = r"C:\Users\amusa\code\learning\gps1.txt"

# Read the text from the file
with open(file_path, 'r', encoding='utf-8') as the_file:
    text = the_file.read()

# Tokenize the text
text_tok = nltk.word_tokenize(text)

# Perform POS tagging using NLTK
pos_tagged = nltk.pos_tag(text_tok)

# Print the list of tuples: (word, word_class)
print(pos_tagged)

# For loop to extract the elements of the tuples in the pos_tagged list
# Print the word and the pos_tag with the underscore as a delimiter
for word, word_class in pos_tagged:
    print(word + "_" + word_class)
# Out:
# [('The', 'DT'), ('old', 'JJ'), ('man', 'NN'), ('the', 'DT'), ('gate', 'NN'), ('.', '.'), ('The', 'DT'), ('old', 'JJ'), ('dog', 'NN'), ('the', 'DT'), ('footsteps', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('young', 'JJ'), ('.', '.'), ('Fat', 'JJ'), ('people', 'NNS'), ('eat', 'VBP'), ('accumulates', 'NNS'), ('.', '.'), ('The', 'DT'), ('complex', 'JJ'), ('houses', 'NNS'), ('married', 'VBD'), ('and', 'CC'), ('single', 'JJ'), ('students', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('families', 'NNS'), ('.', '.'), ('Your', 'PRP$'), ('take', 'NN'), ('on', 'IN'), ('the', 'DT'), ('matter', 'NN'), ('is', 'VBZ'), ('appreciated', 'VBN'), ('.', '.'), ('Time', 'NNP'), ('flies', 'VBZ'), ('like', 'IN'), ('an', 'DT'), ('arrow', 'NN'), (';', ':'), ('fruit', 'CC'), ('flies', 'NNS'), ('like', 'IN'), ('a', 'DT'), ('banana', 'NN'), ('.', '.'), ('The', 'DT'), ('prime', 'JJ'), ('number', 'NN'), ('few', 'JJ'), ('.', '.'), ('The', 'DT'), ('cotton', 'NN'), ('clothing', 'NN'), ('is', 'VBZ'), ('made', 'VBN'), ('of', 'IN'), ('grows', 'NNS'), ('in', 'IN'), ('Mississippi', 'NNP'), ('.', '.'), ('Until', 'IN'), ('the', 'DT'), ('police', 'NN'), ('arrest', 'VBD'), ('the', 'DT'), ('criminals', 'NNS'), ('control', 'VBP'), ('the', 'DT'), ('street', 'NN'), ('.', '.'), ('He', 'PRP'), ('sent', 'VBD'), ('some', 'DT'), ('men', 'NNS'), ('to', 'TO'), ('police', 'VB'), ('his', 'PRP$'), ('movements', 'NNS'), ('.', '.'), ('I', 'PRP'), ('convinced', 'VBD'), ('her', 'PRP'), ('children', 'NNS'), ('are', 'VBP'), ('noisy', 'JJ'), ('.', '.'), ('Walking', 'VBG'), ('dogs', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('funny', 'JJ'), ('.', '.'), ('Singing', 'NN'), ('is', 'VBZ'), ('my', 'PRP$'), ('hobby', 'NN'), ('.', '.'), ('She', 'PRP'), ('is', 'VBZ'), ('singing', 'VBG'), ('aloud', 'RB'), ('.', '.'), ('The', 'DT'), ('singing', 'JJ'), ('bird', 'NN'), ('is', 'VBZ'), ('beautiful', 'JJ'), ('.', '.'), ('He', 'PRP'), ('walked', 'VBD'), ('in', 'IN'), ('smiling', 'VBG'), ('.', '.'), ('He', 'PRP'), ('found', 'VBD'), ('solace', 'NN'), ('in', 'IN'), ('smiling', 'VBG'), ('.', '.'), ('I', 'PRP'), ('love', 'VBP'), ('to', 'TO'), ('see', 'VB'), ('your', 'PRP$'), ('smiling', 'VBG'), ('face', 'NN'), ('.', '.'), ('She', 'PRP'), ('is', 'VBZ'), ('always', 'RB'), ('smiling', 'VBG'), ('.', '.'), ('Tell', 'VB'), ('me', 'PRP'), ('the', 'DT'), ('walking', 'VBG'), ('distance', 'NN'), ('.', '.'), ('Walking', 'VBG'), ('can', 'MD'), ('be', 'VB'), ('fun', 'RB'), ('.', '.'), ('He', 'PRP'), ('is', 'VBZ'), ('walking', 'VBG'), ('home', 'NN'), ('.', '.'), ('I', 'PRP'), ('need', 'VBP'), ('you', 'PRP'), ('to', 'TO'), ('round', 'VB'), ('the', 'DT'), ('table', 'NN'), ('twice', 'RB'), ('.', '.'), ('The', 'DT'), ('earth', 'NN'), ('turns', 'VBZ'), ('round', 'NN'), ('once', 'RB'), ('.', '.'), ('The', 'DT'), ('world', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('round', 'NN'), ('shape', 'NN'), ('.', '.'), ('You', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('move', 'VB'), ('round', 'NN'), ('the', 'DT'), ('table', 'NN'), ('.', '.'), ('He', 'PRP'), ('won', 'VBD'), ('the', 'DT'), ('third', 'JJ'), ('round', 'NN'), ('.', '.'), ('We', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('table', 'VB'), ('the', 'DT'), ('discussion', 'NN'), ('with', 'IN'), ('him', 'PRP'), ('.', '.'), ('I', 'PRP'), ('need', 'VBP'), ('a', 'DT'), ('table', 'JJ'), ('stand', 'NN'), ('.', '.'), ('That', 'DT'), ('must', 'MD'), ('be', 'VB'), ('the', 'DT'), ('round', 'NN'), ('table', 'NN'), ('.', '.'), ('We', 'PRP'), ('all', 'DT'), ('bank', 'NN'), ('on', 'IN'), ('you', 'PRP'), ('for', 'IN'), ('the', 'DT'), ('job', 'NN'), ('.', '.'), ('He', 'PRP'), ('saw', 'VBD'), ('you', 'PRP'), ('at', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('.', '.'), ('Stand', 'VB'), ('on', 'IN'), ('your', 'PRP$'), ('feet', 'NNS'), ('.', '.'), ('Can', 'MD'), ('I', 'PRP'), ('know', 'VB'), ('your', 'PRP$'), ('stand', 'NN'), ('on', 'IN'), ('the', 'DT'), ('matter', 'NN'), ('.', '.'), ('They', 'PRP'), ('all', 'DT'), ('want', 'VBP'), ('the', 'DT'), ('cook', 'NN'), ('to', 'TO'), ('cook', 'VB'), ('the',  ...
# The_DT
# old_JJ
# man_NN
# the_DT
# gate_NN
# ._.
# The_DT
# old_JJ
# dog_NN
# the_DT
# footsteps_NNS
# of_IN
# the_DT
# young_JJ
# ._.
# Fat_JJ
# people_NNS
# eat_VBP
# accumulates_NNS
# ._.
# The_DT
# complex_JJ
# houses_NNS
# married_VBD
# and_CC
# single_JJ
# students_NNS
# and_CC
# their_PRP$
# families_NNS
# ._.
# Your_PRP$
# take_NN
# on_IN
# the_DT
# matter_NN
# is_VBZ
# appreciated_VBN
# ._.
# Time_NNP
# flies_VBZ
# like_IN
# an_DT
# arrow_NN
# ;_:
# fruit_CC
# flies_NNS
# like_IN
# a_DT
# banana_NN
# ._.
# The_DT
# prime_JJ
# number_NN
# few_JJ
# ._.
# The_DT
# cotton_NN
# clothing_NN
# is_VBZ
# made_VBN
# of_IN
# grows_NNS
# in_IN
# Mississippi_NNP
# ._.
# Until_IN
# the_DT
# police_NN
# arrest_VBD
# the_DT
# criminals_NNS
# control_VBP
# the_DT
# street_NN
# ._.
# He_PRP
# sent_VBD
# some_DT
# men_NNS
# to_TO
# police_VB
# his_PRP$
# movements_NNS
# ._.
# I_PRP
# convinced_VBD
# her_PRP
# children_NNS
# are_VBP
# noisy_JJ
# ._.
# Walking_VBG
# dogs_NNS
# can_MD
# be_VB
# funny_JJ
# ._.
# Singing_NN
# is_VBZ
# my_PRP$
# hobby_NN
# ._.
# She_PRP
# is_VBZ
# singing_VBG
# aloud_RB
# ._.
# The_DT
# singing_JJ
# bird_NN
# is_VBZ
# beautiful_JJ
# ._.
# He_PRP
# walked_VBD
# in_IN
# smiling_VBG
# ._.
# He_PRP
# found_VBD
# solace_NN
# in_IN
# smiling_VBG
# ._.
# I_PRP
# love_VBP
# to_TO
# see_VB
# your_PRP$
# smiling_VBG
# face_NN
# ._.
# She_PRP
# is_VBZ
# always_RB
# smiling_VBG
# ._.
# Tell_VB
# me_PRP
# the_DT
# walking_VBG
# distance_NN
# ._.
# Walking_VBG
# can_MD
# be_VB
# fun_RB
# ._.
# He_PRP
# is_VBZ
# walking_VBG
# home_NN
# ._.
# I_PRP
# need_VBP
# you_PRP
# to_TO
# round_VB
# the_DT
# table_NN
# twice_RB
# ._.
# The_DT
# earth_NN
# turns_VBZ
# round_NN
# once_RB
# ._.
# The_DT
# world_NN
# has_VBZ
# a_DT
# round_NN
# shape_NN
# ._.
# You_PRP
# need_VBP
# to_TO
# move_VB
# round_NN
# the_DT
# table_NN
# ._.
# He_PRP
# won_VBD
# the_DT
# third_JJ
# round_NN
# ._.
# We_PRP
# need_VBP
# to_TO
# table_VB
# the_DT
# discussion_NN
# with_IN
# him_PRP
# ._.
# I_PRP
# need_VBP
# a_DT
# table_JJ
# stand_NN
# ._.
# That_DT
# must_MD
# be_VB
# the_DT
# round_NN
# table_NN
# ._.
# We_PRP
# all_DT
# bank_NN
# on_IN
# you_PRP
# for_IN
# the_DT
# job_NN
# ._.
# He_PRP
# saw_VBD
# you_PRP
# at_IN
# the_DT
# bank_NN
# last_JJ
# night_NN
# ._.
# Stand_VB
# on_IN
# your_PRP$
# feet_NNS
# ._.
# Can_MD
# I_PRP
# know_VB
# your_PRP$
# stand_NN
# on_IN
# the_DT
# matter_NN
# ._.
# They_PRP
# all_DT
# want_VBP
# the_DT
# cook_NN
# to_TO
# cook_VB
# the_DT
# food_NN
# early_RB
# ._.
# I_PRP
# went_VBD
# for_IN
# a_DT
# run_NN
# in_IN
# the_DT
# morning_NN
# ._.
# The_DT
# children_NNS
# like_IN
# to_TO
# run_VB
# in_IN
# the_DT
# park_NN
# ._.
# We_PRP
# met_VBD
# the_DT
# dog_NN
# at_IN
# the_DT
# run_NN
# track_NN
# ._.
# We_PRP
# identified_VBD
# the_DT
# fresh_JJ
# track_NN
# marks_NNS
# ._.
# I_PRP
# need_VBP
# to_TO
# track_VB
# the_DT
# package_NN
# ._.
# The_DT
# hikers_NNS
# followed_VBD
# the_DT
# track_NN
# ._.
# That_DT
# book_NN
# is_VBZ
# mine_JJ
# ._.
# That_DT
# is_VBZ
# my_PRP$
# book_NN
# ._.
# I_PRP
# know_VBP
# that_DT
# love_NN
# is_VBZ
# blind_RB
# ._.
# This_DT
# is_VBZ
# the_DT
# boy_NN
# that_WDT
# won_VBD
# the_DT
# game_NN
# ._.
