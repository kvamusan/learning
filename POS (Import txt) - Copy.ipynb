# %%
import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# %%
with open('SOP.txt', 'r', encoding='utf-8') as the_file:
    text = the_file.read()
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)
# print(len(tokens))

print(pos_tags)
# Out:
# [('STATEMENT', 'NNP'), ('OF', 'NNP'), ('PURPOSE', 'NNP'), ('The', 'DT'), ('field', 'NN'), ('of', 'IN'), ('Linguistics', 'NNP'), ('has', 'VBZ'), ('been', 'VBN'), ('a', 'DT'), ('highly', 'RB'), ('beneficial', 'JJ'), ('academic', 'JJ'), ('discipline', 'NN'), ('to', 'TO'), ('me', 'PRP'), ('.', '.'), ('To', 'TO'), ('add', 'VB'), ('to', 'TO'), ('the', 'DT'), ('existing', 'VBG'), ('body', 'NN'), ('of', 'IN'), ('knowledge', 'NN'), ('and', 'CC'), ('to', 'TO'), ('model', 'VB'), ('my', 'PRP$'), ('work', 'NN'), ('on', 'IN'), ('the', 'DT'), ('principles', 'NNS'), ('of', 'IN'), ('existing', 'VBG'), ('scholars', 'NNS'), ('like', 'IN'), ('Ferdinand', 'NNP'), ('de', 'FW'), ('Saussure', 'NNP'), (',', ','), ('Leonard', 'NNP'), ('Bloomfield', 'NNP'), (',', ','), ('Noam', 'NNP'), ('Chomsky', 'NNP'), (',', ','), ('M.A.K', 'NNP'), ('.', '.'), ('Halliday', 'NNP'), (',', ','), ('George', 'NNP'), ('Lakoff', 'NNP'), (',', ','), ('and', 'CC'), ('so', 'RB'), ('on', 'IN'), (',', ','), ('I', 'PRP'), ('apply', 'VBP
# ...

# %%
type(tokens)
# Out:
# list

# %%
print(tokens[0:20])
# Out:
# ['STATEMENT', 'OF', 'PURPOSE', 'The', 'field', 'of', 'Linguistics', 'has', 'been', 'a', 'highly', 'beneficial', 'academic', 'discipline', 'to', 'me', '.', 'To', 'add', 'to']

# %%
type(text)
# Out:
# str

# %%
print(text[0:25])
# Out:
# STATEMENT OF PURPOSE
# The
